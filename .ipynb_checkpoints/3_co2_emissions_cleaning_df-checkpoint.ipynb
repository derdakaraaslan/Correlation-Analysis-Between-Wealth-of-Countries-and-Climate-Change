# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
path ='./CO2_emission.csv'
df_co2 = pd.read_csv(path)

# %%
df = df_co2.drop(['1990', '1991', '1992', '1993', '1994', '2019.1'], axis=1)
df = pd.melt(df, id_vars=["Country Name", "country_code", "Region", "Indicator Name"],
        var_name="Year", 
        value_name="CO2").sort_values(by=['Country Name', 'Year'])
df['Year'] = df['Year'].astype(int)

# %%
df
# Out:
#      Country Name country_code              Region  \
# 1     Afghanistan          AFG          South Asia
# 216   Afghanistan          AFG          South Asia
# 431   Afghanistan          AFG          South Asia
# 646   Afghanistan          AFG          South Asia
# 861   Afghanistan          AFG          South Asia
# ...           ...          ...                 ...
# 4514     Zimbabwe          ZWE  Sub-Saharan Africa
# 4729     Zimbabwe          ZWE  Sub-Saharan Africa
# 4944     Zimbabwe          ZWE  Sub-Saharan Africa
# 5159     Zimbabwe          ZWE  Sub-Saharan Africa
# 5374     Zimbabwe          ZWE  Sub-Saharan Africa
#
#                               Indicator Name  Year       CO2
# 1     CO2 emissions (metric tons per capita)  1995  0.068468
# 216   CO2 emissions (metric tons per capita)  1996  0.062588
# 431   CO2 emissions (metric tons per capita)  1997  0.056827
# 646   CO2 emissions (metric tons per capita)  1998  0.052691
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5375 entries, 1 to 5374
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    5375 non-null   object
#  1   country_code    5375 non-null   object
#  2   Region          5375 non-null   object
#  3   Indicator Name  5375 non-null   object
#  4   Year            5375 non-null   int32
#  5   CO2             4766 non-null   float64
# dtypes: float64(1), int32(1), object(4)
# memory usage: 272.9+ KB

# %% [markdown]
# Checking for null and duplicates values

# %%
print("The missing values are:\n{}".format(df.isnull().sum()))
print("\nThe duplicated values are:{}".format(len(df[df.duplicated()])))
# Out:
# The missing values are:
# Country Name        0
# country_code        0
# Region              0
# Indicator Name      0
# Year                0
# CO2               609
# dtype: int64
#
# The duplicated values are:0

# %% [markdown]
# Removing null and duplicate values from dataset

# %%
df.dropna(inplace = True)
print("The missing values are:\n{}".format(df.isnull().sum()))
print("\nThe duplicated values are:{}".format(len(df[df.duplicated()])))
# Out:
# The missing values are:
# Country Name      0
# country_code      0
# Region            0
# Indicator Name    0
# Year              0
# CO2               0
# dtype: int64
#
# The duplicated values are:0

# %% [markdown]
# Removing outliners

# %%
for i in df[['CO2']]:
    plt.figure()
    sns.boxplot(df, x=df[i], orient="h")

# %%
df = df[df['CO2'] < 10]
df
# Out:
#      Country Name country_code              Region  \
# 1     Afghanistan          AFG          South Asia
# 216   Afghanistan          AFG          South Asia
# 431   Afghanistan          AFG          South Asia
# 646   Afghanistan          AFG          South Asia
# 861   Afghanistan          AFG          South Asia
# ...           ...          ...                 ...
# 4514     Zimbabwe          ZWE  Sub-Saharan Africa
# 4729     Zimbabwe          ZWE  Sub-Saharan Africa
# 4944     Zimbabwe          ZWE  Sub-Saharan Africa
# 5159     Zimbabwe          ZWE  Sub-Saharan Africa
# 5374     Zimbabwe          ZWE  Sub-Saharan Africa
#
#                               Indicator Name  Year       CO2
# 1     CO2 emissions (metric tons per capita)  1995  0.068468
# 216   CO2 emissions (metric tons per capita)  1996  0.062588
# 431   CO2 emissions (metric tons per capita)  1997  0.056827
# 646   CO2 emissions (metric tons per capita)  1998  0.052691
# ...

# %%
df.to_csv('cleaned_CO2_emission.csv', index=False)
